# %%
import requests
import pandas as pd
import numpy as np
from cities import *
from specialties import *

# %% [markdown]
# We're starting with Kaiser because Kaiser really slays with this. I also have much more familiarity with Kaiser so we're starting here.

# %%
# Provider taxonomy codes
psychology = '103T00000X'
psychiatry = '2084P0800X'
lcsw = '1041C0700X'

# %%
# KP Region Organization refs fd9c0ae4-e05f-bf25-aadf-219aff63590b
kpnw = '6195d4cb-11d0-6bc8-6833-9233b7361939'
ncal = 'ef11a240-e52e-8dd4-52db-6a9256d52217'
scal = '5fdd4a0e-7fc3-970a-7b52-bb9198666a22'
kpco = '0ed5a029-9844-c608-ee6a-0bc2a35a0123'
kphi = '493944e8-3364-4923-a8b2-a3044d5269a2'
masr = 'b65fbd8f-abc3-8471-55b3-56a1f6d5d134'
kpga = 'db417117-c802-aa23-cc9a-ab53aedd786e'
kpwa = '3befcdee-20ab-b3bc-d4d2-b3fdf6dc288f'

# %%
# KP API variables
base = 'https://kpx-service-bus.kp.org/service/hp/mhpo/healthplanproviderv1rc/'
hcs = 'HealthcareService'
loc = 'Location'
org = 'Organization'
dr = 'Practitioner'
role = 'PractitionerRole'

# %%
# Bay Area Cities
bay_area = np.array([east_bay])
bay_area = np.append(bay_area, south_bay).flatten()
bay_area = np.append(bay_area, peninsula).flatten()
bay_area = np.append(bay_area, north_bay).flatten()

bay_area.shape
# Out:
# (196,)

# %% [markdown]
# Keep these code snippets for reference. These three resources can successfully be queried by location in the following manner:
# * `#requests.get(base + loc + '?address-city=Dublin&address-state=CA').json()`
# * `#requests.get(base + hcs + '?location.address-city=Dublin&location.address-state=CA').json()`
# * `#requests.get(base + role + '?location.address-city=Dublin&location.address-state=Ca').json()`

# %% [markdown]
# For now, we will start with creating a small version of the KP product. We'll start, of course, with the city of Berkeley

# %%
berk_loc_bundle = requests.get(base + loc + '?address-city=Berkeley&address-state=CA&_count=100').json()

# %%
# Create useful variables
total_items = berk_loc_bundle['total']
total_iterations = (total_items // 100) + 1
obj = berk_loc_bundle['entry']
iteration = 1
loc_refs = np.array([])
loc_names = np.array([])
loc_addresses = np.array([])
loc_statuses = np.array([])

# For loop
while iteration <= total_iterations:
    next_url = berk_loc_bundle['link'][1]['url']
    for item in obj:
        resource = item['resource']
        # Find values in Location resource item
        ref = resource['id']
        name = resource['identifier'][0]['value']
        address = resource['address']['text']
        status = resource['status']
        
        # Append to array
        loc_refs = np.append(loc_refs, ref)
        loc_names = np.append(loc_names, name)
        loc_addresses = np.append(loc_addresses, address)
        loc_statuses = np.append(loc_statuses, status)
    
    # Finished with items in obj; reinitialize variables
    berk_loc_bundle = requests.get(next_url).json()
    obj = berk_loc_bundle['entry']
    iteration += 1
        
# Create Location DataFrame
berk_loc_df = pd.DataFrame(data={'id':loc_refs,
                                 'name':loc_names,
                                 'address':loc_addresses,
                                 'status':loc_statuses})

# %%
berk_loc_df.head()
# Out:
#                                      id  \
# 0  505ece60-3e81-b340-236a-30c4b1a1eb6c
# 1  36aaf6d9-7ba6-8994-c1a3-bbc3ac004565
# 2  c6a361af-d878-3a12-28ce-3631c09a1985
# 3  6ff0fd5a-2116-3179-7ed7-20ef0b3324b3
# 4  de104892-e14b-014d-a3d1-156fe9149aa2
#
#                                              name  \
# 0      Clifford_Feldman2855_Telegraph_Ave_Ste_204
# 1        Peter_Freedman3031_Telegraph_Ave_Ste_103
# 2    Yelena_Sirbiladze1942_University_Ave_Ste_208
# 3                  Richard_Unger2607_Alcatraz_Ave
# 4  Haleh_Nekoorad*Long1942_University_Ave_Ste_208
#
#                                           address  status
# 0   2855 Telegraph Ave Ste 204 Berkeley, CA 94705  active
# 1   3031 Telegraph Ave Ste 103 Berkeley, CA 94705  active
# 2  1942 University Ave Ste 208 Berkeley, CA 94704  active
# 3            2607 Alcatraz Ave Berkeley, CA 94705  active
# 4  1942 University Ave Ste 208 Berkeley, CA 94704  active

# %% [markdown]
# Now, let's validate this DataFrame

# %%
berk_loc_df.shape[0] == total_items
# Out:
# True

# %%
len(berk_loc_df['id'].unique()) == berk_loc_df.shape[0]
# Out:
# True

# %%
len(berk_loc_df['name'].unique()) == berk_loc_df.shape[0]
# Out:
# True

# %% [markdown]
# Keep these code snippets for reference. These three resources can successfully be queried by location in the following manner:
# * `#requests.get(base + loc + '?address-city=Dublin&address-state=CA').json()`
# * `#requests.get(base + hcs + '?location.address-city=Dublin&location.address-state=CA').json()`
# * `#requests.get(base + role + '?location.address-city=Dublin&location.address-state=Ca').json()`

# %% [markdown]
# The Location DataFrame looks good!! Now, let's focus on creating the Provider DataFrame. Again, we'll start with a small subset by looking at the City of Berkeley.

# %%
berk_psychology_bundle = requests.get(base + hcs + f'?location.address-city=Berkeley&location.address-state=CA&specialty={lcsw}&_count=100').json()

# %%
# Create useful variables
total_items = berk_psychology_bundle['total']
total_iterations = (total_items // 100) + 1
obj = berk_psychology_bundle['entry']
iteration = 1
hcs_refs = np.array([])
hcs_loc_refs = np.array([])
hcs_names = np.array([])
hcs_specialties = np.array([])
hcs_statuses = np.array([])
hcs_phones = np.array([])
hcs_languages = np.array([])

# For loop
while iteration <= total_iterations:
    if total_iterations > 1:
        next_url = berk_psychology_bundle['link'][1]['url']
    else:
        next_url = None
    for item in obj:
        resource = item['resource']
        # Find values in Location resource item
        ref = resource['id']
        loc_ref = resource['location'][0]['reference'][9:]
        name = resource['name']
        specialty = resource['specialty'][0]['coding'][0]['display']
        status = resource['active']
        phone = resource['telecom'][0]['value']
        language = resource['language']
        
        # Append to array
        hcs_refs = np.append(hcs_refs, ref)
        hcs_loc_refs = np.append(hcs_loc_refs, loc_ref)
        hcs_names = np.append(hcs_names, name)
        hcs_specialties = np.append(hcs_specialties, specialty)
        hcs_statuses = np.append(hcs_statuses, status)
        hcs_phones = np.append(hcs_phones, phone)
        hcs_languages = np.append(hcs_languages, language)
    
    # Finished with items in obj; reinitialize variables
    if total_iterations > 1:
        berk_psychology_bundle = requests.get(next_url).json()
        obj = berk_psychology_bundle['entry']
        iteration += 1
    else:
        break
        
# Create Location DataFrame
berk_psychology_df = pd.DataFrame(data={'id':hcs_refs,
                                        'location':hcs_loc_refs,
                                        'name':hcs_names,
                                        'specialty':hcs_specialties,
                                        'staus':hcs_statuses,
                                        'phone':hcs_phones,
                                        'language':hcs_languages})

# %%
berk_psychology_df.head()
# Out:
#                                      id                              location  \
# 0  0810d773-67af-4aa9-aa31-3083991765b8  2a05d24c-70a9-4b80-8ac5-27e010df0bb5
# 1  8e4c30bf-0050-4dc8-8ec6-7f59ea473324  981f78e0-d797-45ca-aa26-2363b0c173ea
# 2  c04e3025-9a69-49e0-9187-d7dd9e43ec83  981f78e0-d797-45ca-aa26-2363b0c173ea
# 3  e472ac41-9321-4f53-9d7c-f54b35e4e1af  f676ca79-bfe9-4c47-a0ab-1b422c9cb4c2
# 4  0c66d912-1661-4415-90d3-8867ee096d9b  1bf50e91-5c22-4a83-a99f-52bb62631c3c
#
#                        name               specialty  staus           phone  \
# 0       Esther Martino LCSW  Clinical Social Worker    1.0  (510) 406-4166
# 1  Family Spring Psychology  Clinical Social Worker    1.0  (510) 470-5777
# 2  Family Spring Psychology  Clinical Social Worker    1.0  (510) 470-5777
# 3        Patricia B. Becker  Clinical Social Worker    1.0  (510) 704-0707
# 4   Nicholas Rosenberg LCSW  Clinical Social Worker    1.0  (510) 868-5911
#
#   language
# 0    en-US
# 1    en-US
# 2    en-US
# 3    en-US
# 4    en-US

# %% [markdown]
# Now that we've successfully created a mini Location DataFrame and Providers DataFrame, let's repeat the process for multiple cities in the East Bay.

# %%
loc_refs = np.array([])
loc_names = np.array([])
loc_addresses = np.array([])
loc_cities = np.array([])
loc_zips = np.array([])
loc_statuses = np.array([])

for city in bay_area:
    city_loc_bundle = requests.get(base + loc + f'?address-city={city}&address-state=CA&_count=100').json()
    
    # Check if city has any Locations
    if not city_loc_bundle['total']:
        continue
    else: 
        # Create useful variables
        total_items = city_loc_bundle['total']
        total_iterations = (total_items // 100) + 1
        obj = city_loc_bundle['entry']
        iteration = 1

        # For loop
        while iteration <= total_iterations:
            # Check if no pagination required
            if total_items <= 100:
                next_url = None
            else:
                next_url = city_loc_bundle['link'][1]['url']
            for item in obj:
                resource = item['resource']
                # Find values in Location resource item
                ref = resource['id']
                name = resource['identifier'][0]['value']
                address = resource['address']['text']
                city_name = resource['address']['city']
                zip_code = resource['address']['postalCode']
                status = resource['status']

                # Append to array
                loc_refs = np.append(loc_refs, ref)
                loc_names = np.append(loc_names, name)
                loc_addresses = np.append(loc_addresses, address)
                loc_cities = np.append(loc_cities, city_name)
                loc_zips = np.append(loc_zips, zip_code)
                loc_statuses = np.append(loc_statuses, status)

            # Finished with items in obj; reinitialize variables
            if total_items > 100:
                city_loc_bundle = requests.get(next_url).json()
                obj = city_loc_bundle['entry']
            iteration += 1

# Create Location DataFrame
loc_df = pd.DataFrame(data={'id':loc_refs,
                            'name':loc_names,
                            'address':loc_addresses,
                            'city':loc_cities,
                            'zip':loc_zips,
                            'status':loc_statuses})

# %%
loc_df
# Out:
#                                         id  \
# 0     27e47aee-88fd-8b36-fb64-a886f919bb5e
# 1     bc15e6af-0d67-cfcf-dee1-cda4edd906ca
# 2     622f3ab9-3128-a996-95bb-444b5c162ab8
# 3     8f574a93-ca0a-64c9-dec3-2055784e970c
# 4     9123f200-db09-b591-a655-12828e0d77be
# ...                                    ...
# 5985  87d1a900-56aa-4a74-a00e-f7e5b43bbd40
# 5986  8cf87283-da5a-4604-b063-d38680225971
# 5987  b0e93f08-bd24-473f-ace3-3f34cf7bcea1
# 5988  f07f06d0-7dc7-41e7-a74b-be2be81d5900
# 5989  845ebd88-2f3d-4aec-ab09-b6229c9ce306
#
#                                                    name  \
# 0                  Michael_San_Jose2179_Harbor_Bay_Pkwy
# 1              Michael_Knoll_DDS_MD2242_Santa_Clara_Ave
# 2     Alameda_Landing_Dentistry_Dental_Group2660_5th...
# 3               Dennis_Robles2258_Santa_Clara_Ave_Ste_4
# 4             Bright_Now_Dental_Alameda2140_S_Shore_Ctr
# ...                                                 ...
# 5985  1466788699*STEPHEN_TESSLER_PHD*CN_310017461700...
# 5986                                             339937
# 5987                                             363608
# 5988                                             363094
# 5989                                             410896
#
#                                            address     city         zip  \
# 0           2179 Harbor Bay Pkwy Alameda, CA 94502  Alameda       94502
# 1           2242 Santa Clara Ave Alameda, CA 94501  Alameda       94501
# 2              2660 5th St Ste C Alameda, CA 94501  Alameda       94501
# 3     2258 Santa Clara Ave Ste 4 Alameda, CA 94501  Alameda       94501
# 4               2140 S Shore Ctr Alameda, CA 94501  Alameda       94501
# ...                                            ...      ...         ...
# 5985      1140 Pitt School Rd Ste F Dixon CA 95620    Dixon       95620
# 5986        1640 N Lincoln St , Dixon , CA , 95620    Dixon       95620
# 5987     1057 N First St , Dixon , CA , 95620-0000    Dixon  95620-0000
# 5988  1235 Stratford Ave , Dixon , CA , 95620-2024    Dixon  95620-2024
# 5989     235 E Dorset Dr , Dixon , CA , 95620-9232    Dixon  95620-9232
#
#       status
# 0     active
# 1     active
# 2     active
# 3     active
# 4     active
# ...      ...
# 5985  active
# 5986  active
# 5987  active
# 5988  active
# 5989  active
#
# [5990 rows x 6 columns]

# %%
loc_df['city'].value_counts()
# Out:
# San Jose         1454
# San Francisco     615
# Berkeley          287
# Oakland           269
# Santa Rosa        241
#                  ...
# Deer Park           1
# Atherton            1
# San Martin          1
# Bethel Island       1
# Colma               1
# Name: city, Length: 112, dtype: int64

# %%
hcs_refs = np.array([])
hcs_loc_refs = np.array([])
hcs_names = np.array([])
hcs_specialties = np.array([])
hcs_statuses = np.array([])
hcs_phones = np.array([])
hcs_languages = np.array([])

for city in bay_area:
    for specialty in mental_health:
        city_hcs_bundle = requests.get(base + hcs + f'?location.address-city={city}&location.address-state=CA&specialty={specialty}&_count=100').json()

        # Check if city has any Locations
        if not city_hcs_bundle['total']:
            continue
        else: 
            # Create useful variables
            total_items = city_hcs_bundle['total']
            total_iterations = (total_items // 100) + 1
            obj = city_hcs_bundle['entry']
            iteration = 1

            # For loop
            while iteration <= total_iterations:
                # Check if no pagination required
                if total_items <= 100:
                    next_url = None
                else:
                    next_url = city_hcs_bundle['link'][1]['url']
                for item in obj:
                    resource = item['resource']
                    # Find values in Location resource item
                    ref = resource['id']
                    loc_ref = resource['location'][0]['reference'][9:]
                    name = resource['name']
                    try:
                        specialty = resource['specialty'][0]['coding'][0]['display']
                    except KeyError:
                        specialty = 'N/A'
                    status = resource['active']
                    phone = resource['telecom'][0]['value']
                    language = resource['language']

                    # Append to array
                    hcs_refs = np.append(hcs_refs, ref)
                    hcs_loc_refs = np.append(hcs_loc_refs, loc_ref)
                    hcs_names = np.append(hcs_names, name)
                    hcs_specialties = np.append(hcs_specialties, specialty)
                    hcs_statuses = np.append(hcs_statuses, status)
                    hcs_phones = np.append(hcs_phones, phone)
                    hcs_languages = np.append(hcs_languages, language)

                # Finished with items in obj; reinitialize variables
                if total_items > 100:
                    city_hcs_bundle = requests.get(next_url).json()
                    obj = city_hcs_bundle['entry']
                iteration += 1

# Create Location DataFrame
providers_df = pd.DataFrame(data={'id':hcs_refs,
                                  'location':hcs_loc_refs,
                                  'name':hcs_names,
                                  'specialty':hcs_specialties,
                                  'status':hcs_statuses,
                                  'phone':hcs_phones,
                                  'language':hcs_languages})

# %%
providers_df
# Out:
#                                         id  \
# 0     f8ea8862-ba0f-4905-b00c-a3ab28f3d819
# 1     f589fd77-9d20-457c-a264-a0dd89167469
# 2     df28b621-2f5b-41b4-a74d-ecd88966fe62
# 3     56809ca7-e288-496c-aa49-b7173efd66a0
# 4     025bb7c0-1082-4ff7-9f16-97727604cdd0
# ...                                    ...
# 2342  8890cf8b-c8a6-441f-98be-4301724a6cbf
# 2343  16cc2835-b8fa-4736-a5d8-6fe2cc985346
# 2344  88701929-d498-4edd-aacb-b38c443b19ca
# 2345  3dce5d7a-cdb4-4651-9e42-33c314a250dc
# 2346  411541e6-9af8-4052-8b9e-1f8a75a7fbc3
#
#                                   location                     name  \
# 0     3e281440-d05e-4be1-84b2-4466c65e9d04  Alameda Medical Offices
# 1     d18fd0c2-6a6a-4a8c-8786-7d330e527a02   Oakland Medical Center
# 2     d18fd0c2-6a6a-4a8c-8786-7d330e527a02   Oakland Medical Center
# 3     40d40516-ab20-4bdb-beba-da3d68e8dd6e   Oakland Medical Center
# 4     c56a5310-a5e8-48c8-8fda-fc169257cc36   Oakland Medical Center
# ...                                    ...                      ...
# 2342  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2343  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2344  9f47965a-5a75-4851-bc8e-e909d22722c3     Sandi Rene Gundersen
# 2345  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2346  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
#
#                    specialty  status           phone language
# 0     Clinical Social Worker     1.0  (866) 454-8855    en-US
# 1               Psychologist     1.0  (866) 454-8855    en-US
# 2               Psychologist     1.0  (866) 454-8855    en-US
# 3               Psychologist     1.0  (866) 454-8855    en-US
# 4               Psychologist     1.0  (866) 454-8855    en-US
# ...                      ...     ...             ...      ...
# 2342  Clinical Social Worker     1.0  (866) 454-8855    en-US
# 2343  Clinical Social Worker     1.0  (866) 454-8855    en-US
# 2344  Clinical Social Worker     1.0  (707) 373-7987    en-US
# 2345  Clinical Social Worker     1.0  (866) 454-8855    en-US
# 2346  Clinical Social Worker     1.0  (866) 454-8855    en-US
#
# [2347 rows x 7 columns]

# %%
providers_df['specialty'].value_counts()
# Out:
# Psychologist              806
# Clinical Social Worker    748
# Psychiatry Physician      449
# N/A                       344
# Name: specialty, dtype: int64

# %%
providers_df['name'].value_counts()
# Out:
# Grow Healthcare Group - Norcal - This Location Offers Telehealth Services Only    364
# Oakland Medical Center                                                            156
# Walnut Creek Medical Center                                                       112
# San Francisco Medical Center                                                      111
# San Leandro Medical Center                                                         94
#                                                                                  ...
# Vortex Psychiatry                                                                   1
# Denise Jones-kazan LCSW                                                             1
# Manda Selva LCSW                                                                    1
# Minoo Mehdikhan - San Jose                                                          1
# Sandi Rene Gundersen                                                                1
# Name: name, Length: 283, dtype: int64

# %% [markdown]
# Now let's join the DataFrames together. Let's jot down some notes so that we ensure the join is conducted correctly:
# * Location DataFrame includes Location items of all specialties. We only care about the ones who are referenced in the Providers DataFrame
# * We want all the information from the Providers DataFrame and everything except `name` from the Location DataFrame
# * We'll join on Location resource references; in the Providers DataFrame this is `location`, in the Location DataFrame, this is `id`
# * We'll perform an inner left join

# %%
merged = providers_df.merge(right=loc_df,
                            how='left',
                            left_on='location',
                            right_on='id')
merged = merged.rename(columns={'id_x':'provider_id',
                                'name_x':'name',
                                'status_x':'provider_status',
                                'id_y':'location_id', # Drop
                                'name_y':'location_name', # Drop
                                'status_y':'location_status'}) \
               .drop(['location_id', 'location_name'], axis=1)
merged
# Out:
#                                provider_id  \
# 0     f8ea8862-ba0f-4905-b00c-a3ab28f3d819
# 1     f589fd77-9d20-457c-a264-a0dd89167469
# 2     df28b621-2f5b-41b4-a74d-ecd88966fe62
# 3     56809ca7-e288-496c-aa49-b7173efd66a0
# 4     025bb7c0-1082-4ff7-9f16-97727604cdd0
# ...                                    ...
# 2352  8890cf8b-c8a6-441f-98be-4301724a6cbf
# 2353  16cc2835-b8fa-4736-a5d8-6fe2cc985346
# 2354  88701929-d498-4edd-aacb-b38c443b19ca
# 2355  3dce5d7a-cdb4-4651-9e42-33c314a250dc
# 2356  411541e6-9af8-4052-8b9e-1f8a75a7fbc3
#
#                                   location                     name  \
# 0     3e281440-d05e-4be1-84b2-4466c65e9d04  Alameda Medical Offices
# 1     d18fd0c2-6a6a-4a8c-8786-7d330e527a02   Oakland Medical Center
# 2     d18fd0c2-6a6a-4a8c-8786-7d330e527a02   Oakland Medical Center
# 3     40d40516-ab20-4bdb-beba-da3d68e8dd6e   Oakland Medical Center
# 4     c56a5310-a5e8-48c8-8fda-fc169257cc36   Oakland Medical Center
# ...                                    ...                      ...
# 2352  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2353  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2354  9f47965a-5a75-4851-bc8e-e909d22722c3     Sandi Rene Gundersen
# 2355  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
# 2356  c2e7733d-b7be-44e6-8fe7-2b5a23aa7ce7   Vallejo Medical Center
#
#                    specialty  provider_status           phone language  \
# 0     Clinical Social Worker              1.0  (866) 454-8855    en-US
# 1               Psychologist              1.0  (866) 454-8855    en-US
# 2               Psychologist              1.0  (866) 454-8855    en-US
# 3               Psychologist              1.0  (866) 454-8855    en-US
# 4               Psychologist              1.0  (866) 454-8855    en-US
# ...                      ...              ...             ...      ...
# 2352  Clinical Social Worker              1.0  (866) 454-8855    en-US
# 2353  Clinical Social Worker              1.0  (866) 454-8855    en-US
# 2354  Clinical Social Worker              1.0  (707) 373-7987    en-US
# 2355  Clinical Social Worker              1.0  (866) 454-8855    en-US
# 2356  Clinical Social Worker              1.0  (866) 454-8855    en-US
#
#                                         address     city    zip  \
# 0          2417 Central Avenue Alameda CA 94501  Alameda  94501
# 1                3900 Broadway Oakland CA 94611  Oakland  94611
# 2                3900 Broadway Oakland CA 94611  Oakland  94611
# 3             3801 Howe Street Oakland CA 94611  Oakland  94611
# 4                3505 Broadway Oakland CA 94611  Oakland  94611
# ...                                         ...      ...    ...
# 2352      1761 Broadway Street Vallejo CA 94589  Vallejo  94589
# 2353      1761 Broadway Street Vallejo CA 94589  Vallejo  94589
# 2354  631 Tennessee St Ste 201 Vallejo CA 94590  Vallejo  94590
# 2355      1761 Broadway Street Vallejo CA 94589  Vallejo  94589
# 2356      1761 Broadway Street Vallejo CA 94589  Vallejo  94589
#
#      location_status
# 0             active
# 1             active
# 2             active
# 3             active
# 4             active
# ...              ...
# 2352          active
# 2353          active
# 2354          active
# 2355          active
# 2356          active
#
# [2357 rows x 11 columns]

# %%
merged['location'].value_counts()
# Out:
# 6690f29c-fe37-4fed-af8e-2d9ea3384c25    104
# d18fd0c2-6a6a-4a8c-8786-7d330e527a02     76
# fc66ad11-718f-4142-9457-c599a7d7db5f     68
# 2f726f35-0d11-4d35-809c-43a49a70cd69     65
# b3efffbe-be6c-4ca4-aafa-b37622ed3a6e     56
#                                        ...
# dd5639f1-67c0-4e99-ae58-2e02713af259      1
# 15d585d6-4406-49df-85f2-ed8f612c141a      1
# f16d31dd-358f-43b0-9f48-e71d19f847c6      1
# 23f56233-6ecf-4d40-a734-d2f0b94d9739      1
# 9f47965a-5a75-4851-bc8e-e909d22722c3      1
# Name: location, Length: 709, dtype: int64
