# %%
# Run this cell!
from datascience import *
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import folium
import requests

# %% [markdown]
# # Anthem Test Notebook

# %%
url = 'https://cmsmanapi.anthem.com/fhir/cms_mandate/mcd/Location?address-state=CA'

# Pull data from carrier API
request = requests.get(url)
json_object = request.json()
json_object
# Out:
# {'resourceType': 'Bundle',
#  'type': 'searchset',
#  'id': 'cba567d1-0442-4348-b0f8-02245b08e45a',
#  'meta': {'lastUpdated': '2022-11-10T15:22:16.168-0500',
#   'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#  'timestamp': '2022-11-10T15:22:16.168-0500',
#  'link': [{'relation': 'self',
#    'url': 'https://cmsmanapi.anthem.com/fhir/cms_mandate/mcd/Location?address-state=CA&pageNumber=1'},
#   {'relation': 'next',
#    'url': 'https://cmsmanapi.anthem.com/fhir/cms_mandate/mcd/Location?address-state=CA&pageNumber=2&totalPages=31871'},
#   {'relation': 'Previous', 'url': ''}],
#  'entry': [{'_id': '10001',
#    'resourceType': 'Location',
#    '_Loc_ID': '1',
#    'id': '10001',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '1'}],
#    'status': 'active',
#    'name': 'Oc Cardiovascular Care',
#    'telecom': [{'system': 'Phone', 'value': '9516561500', 'use': 'work'},
#     {'system': 'fax', 'value': '7144862130', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '11180 Warner Ave FOUNTAIN VALLEY, CA 92708',
#     'line': ['11180 Warner Ave'],
#     'city': 'FOUNTAIN VALLEY',
#     'district': '059',
#     'state': 'CA',
#     'postalCode': '92708',
#     'country': 'US'},
#    'position': {'longitude': -117.933364, 'latitude': 33.716355}},
#   {'_id': '10002',
#    'resourceType': 'Location',
#    '_Loc_ID': '2',
#    'id': '10002',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '2'}],
#    'status': 'active',
#    'name': 'Community Psychiatry Associates Dublin',
#    'telecom': [{'system': 'Phone', 'value': '9165767900', 'use': 'work'},
#     {'system': 'fax', 'value': '9162850338', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '3835 N Freeway Blvd SACRAMENTO, CA 95834',
#     'line': ['3835 N Freeway Blvd'],
#     'city': 'SACRAMENTO',
#     'district': '067',
#     'state': 'CA',
#     'postalCode': '95834',
#     'country': 'US'},
#    'position': {'longitude': -121.489064, 'latitude': 38.639564}},
#   {'_id': '10010',
#    'resourceType': 'Location',
#    '_Loc_ID': '10',
#    'id': '10010',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '10'}],
#    'status': 'active',
#    'name': 'Faculty Physicians & Surgeons of Llusm',
#    'telecom': [{'system': 'Phone', 'value': '9093827100', 'use': 'work'},
#     {'system': 'fax', 'value': '9093827101', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '1454 E 2nd St SAN BERNARDINO, CA 92408',
#     'line': ['1454 E 2nd St'],
#     'city': 'SAN BERNARDINO',
#     'district': '071',
#     'state': 'CA',
#     'postalCode': '92408',
#     'country': 'US'},
#    'position': {'longitude': -117.267665, 'latitude': 34.102719}},
#   {'_id': '10014',
#    'resourceType': 'Location',
#    '_Loc_ID': '14',
#    'id': '10014',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '14'}],
#    'status': 'active',
#    'name': 'Tuan Dai Le MD',
#    'telecom': [{'system': 'Phone', 'value': '9096208436', 'use': 'work'},
#     {'system': 'email', 'value': 'tuandailemoinc@gmail.com', 'use': 'work'},
#     {'system': 'fax', 'value': '9098685134', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '1151 E Holt Ave POMONA, CA 91767',
#     'line': ['1151 E Holt Ave'],
#     'city': 'POMONA',
#     'district': '037',
#     'state': 'CA',
#     'postalCode': '91767',
#     'country': 'US'},
#    'position': {'longitude': -117.728796, 'latitude': 34.062897}},
#   {'_id': '10019',
#    'resourceType': 'Location',
#    '_Loc_ID': '19',
#    'id': '10019',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '19'}],
#    'status': 'active',
#    'name': 'Rheumatology And Arthritis Medical Clinic',
#    'telecom': [{'system': 'Phone', 'value': '7604361155', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '230 2nd St Ste 102 Encinitas, CA 92024',
#     'line': ['230 2nd St Ste 102'],
#     'city': 'Encinitas',
#     'district': '073',
#     'state': 'CA',
#     'postalCode': '92024',
#     'country': 'US'},
#    'position': {'longitude': -117.295251, 'latitude': 33.049259}},
#   {'_id': '10024',
#    'resourceType': 'Location',
#    '_Loc_ID': '24',
#    'id': '10024',
#    'meta': {'lastUpdated': '2022-08-16T13:54:01+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '24'}],
#    'status': 'active',
#    'name': 'Ucsf Medical Group Business Services',
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '4150 Clement St Bldg 1 Rm 306d San Francisco, CA 94121',
#     'line': ['4150 Clement St Bldg 1 Rm 306d'],
#     'city': 'San Francisco',
#     'district': '075',
#     'state': 'CA',
#     'postalCode': '94121',
#     'country': 'US'},
#    'position': {'longitude': -122.503647, 'latitude': 37.781145}},
#   {'_id': '10035',
#    'resourceType': 'Location',
#    '_Loc_ID': '35',
#    'id': '10035',
#    'meta': {'lastUpdated': '2022-08-16T13:54:02+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '35'}],
#    'status': 'active',
#    'name': 'Maybury Kenneth B',
#    'telecom': [{'system': 'Phone', 'value': '4154220998', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '3637 California St San Francisco, CA 94118',
#     'line': ['3637 California St'],
#     'city': 'San Francisco',
#     'district': '075',
#     'state': 'CA',
#     'postalCode': '94118',
#     'country': 'US'},
#    'position': {'longitude': -122.454084, 'latitude': 37.78633}},
#   {'_id': '10041',
#    'resourceType': 'Location',
#    '_Loc_ID': '41',
#    'id': '10041',
#    'meta': {'lastUpdated': '2022-08-16T13:54:02+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '41'}],
#    'status': 'active',
#    'name': 'Hill Physicians Medical Group',
#    'telecom': [{'system': 'Phone', 'value': '2096234700', 'use': 'work'},
#     {'system': 'fax', 'value': '2096234712', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '1899 W March Ln STOCKTON, CA 95207',
#     'line': ['1899 W March Ln'],
#     'city': 'STOCKTON',
#     'district': '077',
#     'state': 'CA',
#     'postalCode': '95207',
#     'country': 'US'},
#    'position': {'longitude': -121.32901, 'latitude': 37.987335}},
#   {'_id': '10043',
#    'resourceType': 'Location',
#    '_Loc_ID': '43',
#    'id': '10043',
#    'meta': {'lastUpdated': '2022-08-16T13:54:02+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '43'}],
#    'status': 'active',
#    'name': 'Dr Gary Gold And Associates Optometry',
#    'telecom': [{'system': 'Phone', 'value': '5595829288', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '202 W Myrtle St HANFORD, CA 93230',
#     'line': ['202 W Myrtle St'],
#     'city': 'HANFORD',
#     'district': '031',
#     'state': 'CA',
#     'postalCode': '93230',
#     'country': 'US'},
#    'position': {'longitude': -119.647911, 'latitude': 36.333077}},
#   {'_id': '10046',
#    'resourceType': 'Location',
#    '_Loc_ID': '46',
#    'id': '10046',
#    'meta': {'lastUpdated': '2022-08-16T13:54:02+00:00',
#     'profile': ['http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/plannet-Location']},
#    'extension': [{'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '01',
#         'display': 'Wheel Chair Accessible'}],
#       'text': 'Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '02',
#         'display': 'No Wheel Chair Accessible'}],
#       'text': 'No Wheel Chair Accessible'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': '04',
#         'display': 'Interior Building'}],
#       'text': 'Interior Building'}},
#     {'url': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/StructureDefinition/accessibility',
#      'valueCodeableConcept': {'coding': [{'system': 'http://hl7.org/fhir/us/davinci-pdex-plan-net/CodeSystem/AccessibilityCS',
#         'code': 'handiaccess',
#         'display': 'handicap accessible'}],
#       'text': 'handicap accessible'}}],
#    'identifier': [{'use': 'official',
#      'system': 'http://terminology.anthem.com#Loc_Id',
#      'value': '46'}],
#    'status': 'active',
#    'name': 'Renaissance Imaging Medical Assocs',
#    'telecom': [{'system': 'Phone', 'value': '8055772018', 'use': 'work'},
#     {'system': 'fax', 'value': '8055226401', 'use': 'work'},
#     {'system': 'url', 'value': 'www.rimarad.com', 'use': 'work'}],
#    'address': {'use': 'work',
#     'type': 'both',
#     'text': '18436 Roscoe Blvd NORTHRIDGE, CA 91325',
#     'line': ['18436 Roscoe Blvd'],
#     'city': 'NORTHRIDGE',
#     'district': '037',
#     'state': 'CA',
#     'postalCode': '91325',
#     'country': 'US'},
#    'position': {'longitude': -118.535287, 'latitude': 34.220742}}]}

# %%
len(json_object.get('entry'))
# Out:
# 10
